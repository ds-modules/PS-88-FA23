# %% [markdown]
# # Laboratories of Democratic Backsliding - Jacob M. Grumbach (2022) - Replication

# %% [markdown]
# **General instructions:** these replications will be similar to labs, though with a bit less guidance than we would typically give. An advantage you have is that the answer you are supposed to get for most questions is in the paper.
#
# When we say to "replicate" a table we don't mean you need to reproduce every bit of formatting. Typically for regressions we just want you to verify that the coefficients match those reported in the table. For graphs, the output should look pretty similar, though again you don't need to make the formatting look exactly the same.

# %% [markdown]
# A linguistic note: a tricky thing about this paper is that one of the names of the major parties in the US ("Democratic party") also corresponds to the key outcome variable (level of state democracy). One way we distinguish between these is that when we write Democratic with a capital D we are referring to the party and when we write democratic with a lower-case d we are referring to the kind of governing (or the "regime type" to use standard comparative politics terminology). Be sure to be careful about this distinction, and always be clear whether you are referring to the party or the outcome.

# %%
## Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# ## Part 1: Loading and exploring the data

# %%
## Open Data
df = pd.read_csv("data_grumbach.csv")

# %% [markdown]
# A nice thing to do after loading up any data frame is to use the `.info` function to see what variables are inside. Adding a `verbose=True` argument forces it to display all variables.

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 64 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               950 non-null    int64
#  1   state                    950 non-null    object
#  2   year                     950 non-null    int64
#  3   X                        950 non-null    int64
#  4   st                       950 non-null    object
#  5   partycontrol             931 non-null    float64
#  6   democracy_mcmc           950 non-null    float64
#  7   democracy_mcmc_sd        950 non-null    float64
#  8   democracy_mcmc_se        950 non-null    float64
#  9   democracy_additive       950 non-null    float64
#  10  democracy_mcmc_lib       950 non-null    float64
#  11  democracy_mcmc_lib_sd    950 non-null    float64
#  12  democracy_mcmc_lib_se    950 non-null    float64
#  13  democracy_additive_lib   950 non-null    float64
#  14  unified_r                931 non-null    float64
#  15  unified_d                931 non-null    float64
#  16  divided_govt             931 non-null    float64
#  17  democracy_full_factanal  850 non-null    float64
#  18  pct_black                950 non-null    float64
#  19  pct_white                950 non-null    float64
#  20  pct_latino               950 non-null    float64
#  21  pct_black_lag            950 non-null    float64
#  22  pct_latino_lag           950 non-null    float64
#  23  pct_black_change_ratio   950 non-null    float64
#  24  pct_latino_change_ratio  950 non-null    float64
#  25  pct_black_change         950 non-null    float64
#  26  pct_latino_change        950 non-null    float64
#  27  icpsr                    850 non-null    float64
#  28  hou_chamber              783 non-null    float64
#  29  sen_chamber              796 non-null    float64
#  30  hou_dem                  783 non-null    float64
#  31  hou_rep                  783 non-null    float64
#  32  hou_majority             783 non-null    float64
#  33  sen_dem                  796 non-null    float64
#  34  sen_rep                  796 non-null    float64
#  35  sen_majority             796 non-null    float64
#  36  h_diffs                  783 non-null    float64
#  37  s_diffs                  796 non-null    float64
#  38  h_distance               783 non-null    float64
#  39  s_distance               796 non-null    float64
#  40  h_dem_sd                 783 non-null    float64
#  41  s_dem_sd                 796 non-null    float64
#  42  h_rep_sd                 783 non-null    float64
#  43  s_rep_sd                 792 non-null    float64
#  44  h_chamber_sd             783 non-null    float64
#  45  s_chamber_sd             796 non-null    float64
#  46  polarization_sen         796 non-null    float64
#  47  polarization_hou         783 non-null    float64
#  48  polarization_avg         950 non-null    float64
#  49  rolldemleg               343 non-null    float64
#  50  rolldemvs                350 non-null    float64
#  51  competition_allleg       735 non-null    float64
#  52  competition_votes        350 non-null    float64
#  53  competition_index        735 non-null    float64
#  54  competition_allleg_lag   833 non-null    float64
#  55  competition_votes_lag    400 non-null    float64
#  56  competition_index_lag    833 non-null    float64
#  57  cost_of_voting_index     250 non-null    float64
#  58  vep_turnout              300 non-null    float64
#  59  Democratic               931 non-null    float64
#  60  Republican               931 non-null    float64
#  61  period                   950 non-null    int64
#  62  id                       950 non-null    int64
#  63  placebo                  950 non-null    int64
# dtypes: float64(56), int64(6), object(2)
# memory usage: 475.1+ KB

# %% [markdown]
# One of the key variables we will study is "party control", which is equal to 0 when Republicans have unified control of the state government, 2 when Democrats have unified control of state government, and 1 when there is divided government (e.g., a governer from one party while another party has a majority in the legislature).
#
# We can explore patterns in this variable across states using the `pd.crosstab` function, which creates a table that counts how many observations for each combination of the two variables.

# %%
pd.crosstab(df['state'], df['partycontrol'])
# Out:
# partycontrol    0.0  1.0  2.0
# state
# Alabama           8    8    3
# Alaska            8   11    0
# Arizona          11    8    0
# Arkansas          4    9    6
# California        0    7   12
# Colorado          3   10    6
# Connecticut       0   11    8
# Delaware          0    9   10
# Florida          19    0    0
# Georgia          14    2    3
# Hawaii            0    8   11
# Idaho            19    0    0
# Illinois          0    7   12
# Indiana          10    9    0
# Iowa              2   13    4
# Kansas           11    8    0
# Kentucky          2   17    0
# Louisiana         7    8    4
# Maine             2    9    8
# Maryland          0    8   11
# Massachusetts     0   11    8
# Michigan         11    8    0
# Minnesota         0   17    2
# Mississippi       7    8    4
# Missouri          6   12    1
# Montana           5   14    0
# Nevada            4   15    0
# New Hampshire     4   11    4
# New Jersey        2   10    7
# New Mexico        0   11    8
# New York          0   15    4
# North Carolina    6    4    9
# North Dakota     19    0    0
# Ohio             15    4    0
# Oklahoma          8    9    2
# Oregon            0    9   10
# Pennsylvania      7   12    0
# Rhode Island      0   14    5
# South Carolina   16    3    0
# South Dakota     19    0    0
# Tennessee         8    9    2
# Texas            16    3    0
# Utah             19    0    0
# Vermont           0   10    9
# Virginia          2   17    0
# Washington        0    7   12
# West Virginia     0    5   14
# Wisconsin         7   10    2
# Wyoming          11    8    0

# %% [markdown]
# For example, we can learn from this that over the time period in this data frame, Wyoming had 11 years of unified Republican control, and 8 years of divided government.
#
# **Question 1.1. Make a crosstab of the year variable and party control. What is something we can learn from the table?**

# %%
pd.crosstab(df['year'], df['partycontrol'])
# Out:
# partycontrol  0.0  1.0  2.0
# year
# 2000           15   25    9
# 2001           13   28    8
# 2002           11   29    9
# 2003           12   29    8
# 2004           12   29    8
# 2005           12   29    8
# 2006           12   29    8
# 2007           10   24   15
# 2008           10   25   14
# 2009            9   23   17
# 2010            9   24   16
# 2011           20   18   11
# 2012           21   17   11
# 2013           23   12   14
# 2014           23   11   15
# 2015           23   19    7
# 2016           23   19    7
# 2017           27   15    7
# 2018           27   13    9

# %% [markdown]
# In general there are more states with unified Republican control over the time period. The biggest jump in this direction happens in 2010 (recall the ACA example: this was an election where Republicans made huge gains on the national level too.)

# %% [markdown]
# The key outcome we will study is the state-level democracy index, which is in the "democracy_mcmc" variable. Here is a histogram of that variable:

# %%
df.hist("democracy_mcmc")
# Out:
# array([[<AxesSubplot:title={'center':'democracy_mcmc'}>]], dtype=object)

# %% [markdown]
# We can also take the mean and standard deviation:

# %%
np.mean(df["democracy_mcmc"]), (np.var(df["democracy_mcmc"]))**(1/2)
# Out:
# (-0.0002856776228161125, 0.9227743935135507)

# %% [markdown]
# This variable is loosely normally distributed with mean 0 and standard deviation 1 (by construction), so we can interpret a one unit increase in the state level democracy score as about a one standard deviation increase in how democratic a state is.

# %% [markdown]
# **Question 1.2. Make seperate histograms of the distribution of "democracy_mcmc" for state-years under unified Republican control and unified Democratic control. Interpret any differences you see (hint: note the x axis may be different).**

# %%
df[df["partycontrol"]==0].hist("democracy_mcmc")
df[df["partycontrol"]==2].hist("democracy_mcmc")
# Out:
# array([[<AxesSubplot:title={'center':'democracy_mcmc'}>]], dtype=object)

# %% [markdown]
# The peak of the distribution is close to 0 for both, but there are more positive values for states under Democratic control and more negative values under Republican control.

# %% [markdown]
# **Question 1.3. Use `smf.ols` to fit and summarize a regression with "democracy_mcmc" as the dependent variable and "partycontrol" as in independent variable. Interpret the coefficient on "partycontrol". (Hint: think carefully about one a one unit change in each variable means!)**

# %%
smf.ols('democracy_mcmc ~ partycontrol', data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         democracy_mcmc   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     224.0
# Date:                Fri, 10 Nov 2023   Prob (F-statistic):           1.59e-45
# Time:                        09:44:57   Log-Likelihood:                -1154.3
# No. Observations:                 931   AIC:                             2313.
# Df Residuals:                     929   BIC:                             2322.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.4991      0.043    -11.637      0.000      -0.583      -0.415
# partycontrol     0.5603      0.037     14.965      0.000       0.487       0.634
# ==============================================================================
# Omnibus:                       70.614   Durbin-Watson:                   0.334
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.120
# Skew:                          -0.709   Prob(JB):                     3.28e-19
# Kurtosis:                       3.428   Cond. No.                         2.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The party control variable goes from 0 to 1 to 2 as a state goes from unified R to divided to unified D control. SO, the coefficient says that going from unified R to divided or divide to unified D control is associated with an increase of the democracy score of half a standard deviation.

# %% [markdown]
# **Question 1.4 Why might this coefficient not correspond to a causal effect of party control on the level of democracy?**

# %% [markdown]
# Republicans tend to control the government in more rural and conservative states, which might have a lower level of democracy for other reasons.

# %% [markdown]
# ## Part 2: Replicating Graphs

# %% [markdown]
# Now let's do our first replication of an analysis in the paper, by creating versions of figures 3 and 4. We can do this with the `sns.lineplot` function. If we run this function with year on the x axis and "democray_mcmc" on the y axis it will plot the average of this variable by year. (Set the `ci=0` since the confindence intervals in the paper are doing something different than aht the function does).

# %%
sns.lineplot(data=df, x='year', y='democracy_mcmc', ci=0)
# Out:
# <AxesSubplot:xlabel='year', ylabel='democracy_mcmc'>

# %% [markdown]
# We can also use a `hue='state'` argument to separate out the trend for each state. Though this is kind of messy!

# %%
sns.lineplot(data=df, x='year', y='democracy_mcmc', ci=0, hue='state')
# Out:
# <AxesSubplot:xlabel='year', ylabel='democracy_mcmc'>

# %% [markdown]
# To make a version of figure 3, let's do this but combine all of the states other than NC, TX, and WA in to an "other" category. To do this let's first create a variable called "Stlab" which for now is just "other" for all observations. Then we can overwrite it for North Carolina to be "NC"

# %%
df['Stlab'] = 'Other'
df.loc[df['state'] == "North Carolina", "Stlab"] = "NC"
df.value_counts('Stlab')
# Out:
# Stlab
# Other    931
# NC        19
# dtype: int64

# %% [markdown]
# **Question 2.1. Use `sns.lineplot` to compare the trend of "democracy_mcmc" in North Carolina to all other states.**

# %%
sns.lineplot(x='year', y='democracy_mcmc', data=df, hue="Stlab", ci=0)
# Out:
# <AxesSubplot:xlabel='year', ylabel='democracy_mcmc'>

# %% [markdown]
# **Question 2.2 Change the "Stlab" variable to "TX" for observations corresponding to Texas and "WA" for observations corresponding to Washington. Then use `sns.lineplot` to compare the trends in "democracy_mcmc" of these three states to the average of all other states. Interpret this graph.**

# %%
df.loc[df['state'] == "Washington", "Stlab"] = "WA"
df.loc[df['state'] == "Texas", "Stlab"] = "TX"
sns.lineplot(x='year', y='democracy_mcmc', data=df, hue="Stlab", ci=0)
# Out:
# <AxesSubplot:xlabel='year', ylabel='democracy_mcmc'>

# %% [markdown]
# There is a big drop in NC around 2011, while the other three states and the overall average are relatively flat.

# %% [markdown]
# **Question 2.3. To make something like Figure 4, plot the trend in "democracy_mcmc" by the "partycontrol" variable. (Note this will look somewhat different because the paper uses a method to smooth out the trends. The general idea should be about the same though). Interpret this graph**

# %%
sns.lineplot(data=df, x='year', y='democracy_mcmc', hue='partycontrol', palette=["red", "black", "blue"], 
             ci=None)
# Out:
# <AxesSubplot:xlabel='year', ylabel='democracy_mcmc'>

# %% [markdown]
# Areas with unified R control dip throughout this period, though with some rebound in the last few years. States with divided government have a slight decline through 2012 but then jump up after that. States with D control slightly increase throughout. So there do seem to be different trends by party control, with things potentially getting worse with R control compared to divided and D control.

# %% [markdown]
# ## Part 3: Regressions

# %% [markdown]
# Finally let's replicate some of the regressions in tables 1 and 2.
#
# The regressions in the paper only include observations that have data for all of the key variables. For some state-years there is no data for the "competition" variable, so we drop these values.

# %%
# Drop NaN values to keep 833 observations like the paper
df = df.dropna(subset=['competition_allleg_lag'])

# %% [markdown]
# The models in table 1 all have "democracy_mcmc" as the dependent variable, and also include state and year fixed effects. Recall if we want to make sure a variable is treated as categorical we can include it in the `smf.ols` formula as `...+C(varname)+...`. The other variables used in these regressions are:
# - Competition is in the 'competition_allleg_lag' column
# - Polarization is the 'polarization_avg' column
# - Republican is in the 'republican' column

# %% [markdown]
# *DUE TO HOW THE KEY OUTCOME VARIABLE IS GENERATED, THE COEFFICIENTS IN THE NOTEBOOK WILL BE SLIGHTLY DIFFERENT THAN THE PAPER. SEE HERE FOR VERSION OF TABLES 1 AND 2 WITH COEFFICIENTS THAT YOU SHOULD GET*

# %% [markdown]
# **Question 3.1. Use `smf.ols` to fit and summarize a regression which replicates model 1 in table 1. Note this should include state fixed effects and year fixed effects.**

# %%
reg2 = smf.ols('democracy_mcmc ~ competition_allleg_lag + C(state)+C(year)', data=df).fit()
reg2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         democracy_mcmc   R-squared:                       0.684
# Model:                            OLS   Adj. R-squared:                  0.657
# Method:                 Least Squares   F-statistic:                     25.50
# Date:                Fri, 10 Nov 2023   Prob (F-statistic):          2.62e-150
# Time:                        16:17:05   Log-Likelihood:                -624.10
# No. Observations:                 833   AIC:                             1380.
# Df Residuals:                     767   BIC:                             1692.
# Df Model:                          65
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.7057      0.149     -4.735      0.000      -0.998      -0.413
# C(state)[T.Alaska]             1.1551      0.183      6.312      0.000       0.796       1.514
# C(state)[T.Arizona]            1.0615      0.183      5.786      0.000       0.701       1.422
# C(state)[T.Arkansas]           0.7385      0.185      3.982      0.000       0.374       1.103
# C(state)[T.California]         2.0301      0.183     11.095      0.000       1.671       2.389
# C(state)[T.Colorado]           1.9702      0.187     10.513      0.000       1.602       2.338
# C(state)[T.Connecticut]        1.0811      0.183      5.905      0.000       0.722       1.440
# C(state)[T.Delaware]           0.6307      0.185      3.406      0.001       0.267       0.994
# C(state)[T.Florida]           -0.3104      0.183     -1.692      0.091      -0.670       0.050
# C(state)[T.Georgia]           -0.1708      0.184     -0.928      0.354      -0.532       0.190
# C(state)[T.Hawaii]             1.7654      0.210      8.416      0.000       1.354       2.177
# C(state)[T.Idaho]              1.0348      0.203      5.090      0.000       0.636       1.434
# C(state)[T.Illinois]           1.2821      0.185      6.915      0.000       0.918       1.646
# C(state)[T.Indiana]            0.7713      0.183      4.209      0.000       0.412       1.131
# C(state)[T.Iowa]               1.3946      0.188      7.422      0.000       1.026       1.763
# C(state)[T.Kansas]             1.0126      0.188      5.400      0.000       0.645       1.381
# C(state)[T.Kentucky]           0.4324      0.189      2.288      0.022       0.061       0.803
# C(state)[T.Louisiana]          0.5323      0.183      2.901      0.004       0.172       0.893
# C(state)[T.Maine]              1.4927      0.188      7.922      0.000       1.123       1.863
# C(state)[T.Maryland]           1.4239      0.188      7.590      0.000       1.056       1.792
# C(state)[T.Massachusetts]      1.4642      0.215      6.799      0.000       1.041       1.887
# C(state)[T.Michigan]          -0.1936      0.185     -1.045      0.297      -0.558       0.170
# C(state)[T.Minnesota]          1.3283      0.188      7.071      0.000       0.960       1.697
# C(state)[T.Mississippi]        0.3814      0.184      2.074      0.038       0.020       0.743
# C(state)[T.Missouri]          -0.2956      0.183     -1.614      0.107      -0.655       0.064
# C(state)[T.Montana]            1.3327      0.186      7.163      0.000       0.967       1.698
# C(state)[T.Nevada]             0.9189      0.187      4.914      0.000       0.552       1.286
# C(state)[T.New Hampshire]      0.8774      0.184      4.759      0.000       0.515       1.239
# C(state)[T.New Jersey]         1.8343      0.185      9.897      0.000       1.470       2.198
# C(state)[T.New Mexico]         1.4118      0.184      7.678      0.000       1.051       1.773
# C(state)[T.New York]           1.2652      0.185      6.847      0.000       0.902       1.628
# C(state)[T.North Carolina]     0.7546      0.185      4.084      0.000       0.392       1.117
# C(state)[T.North Dakota]       1.5112      0.184      8.192      0.000       1.149       1.873
# C(state)[T.Ohio]               0.1021      0.183      0.558      0.577      -0.257       0.461
# C(state)[T.Oklahoma]           0.6795      0.184      3.702      0.000       0.319       1.040
# C(state)[T.Oregon]             1.5689      0.188      8.365      0.000       1.201       1.937
# C(state)[T.Pennsylvania]       0.3041      0.187      1.629      0.104      -0.062       0.670
# C(state)[T.Rhode Island]       1.3696      0.215      6.361      0.000       0.947       1.792
# C(state)[T.South Carolina]    -1.5668      0.185     -8.476      0.000      -1.930      -1.204
# C(state)[T.South Dakota]       1.2859      0.188      6.855      0.000       0.918       1.654
# C(state)[T.Tennessee]         -0.2723      0.184     -1.477      0.140      -0.634       0.090
# C(state)[T.Texas]              0.4240      0.184      2.301      0.022       0.062       0.786
# C(state)[T.Utah]               1.1138      0.191      5.826      0.000       0.739       1.489
# C(state)[T.Vermont]            1.2433      0.183      6.791      0.000       0.884       1.603
# C(state)[T.Virginia]          -0.0939      0.186     -0.506      0.613      -0.458       0.271
# C(state)[T.Washington]         2.3135      0.186     12.426      0.000       1.948       2.679
# C(state)[T.West Virginia]      1.0031      0.187      5.352      0.000       0.635       1.371
# C(state)[T.Wisconsin]          0.9434      0.187      5.035      0.000       0.576       1.311
# C(state)[T.Wyoming]            1.4281      0.195      7.323      0.000       1.045       1.811
# C(year)[T.2001]                0.0083      0.108      0.077      0.939      -0.203       0.220
# C(year)[T.2002]               -0.0090      0.108     -0.084      0.933      -0.221       0.203
# C(year)[T.2003]               -0.0073      0.108     -0.068      0.946      -0.219       0.204
# C(year)[T.2004]               -0.1108      0.108     -1.028      0.304      -0.322       0.101
# C(year)[T.2005]               -0.1202      0.108     -1.115      0.265      -0.332       0.091
# C(year)[T.2006]               -0.0786      0.108     -0.729      0.466      -0.290       0.133
# C(year)[T.2007]               -0.0798      0.108     -0.741      0.459      -0.291       0.132
# C(year)[T.2008]               -0.0197      0.108     -0.183      0.855      -0.231       0.192
# C(year)[T.2009]               -0.0130      0.108     -0.120      0.904      -0.225       0.199
# C(year)[T.2010]               -0.1077      0.108     -0.999      0.318      -0.319       0.104
# C(year)[T.2011]               -0.1318      0.108     -1.223      0.222      -0.344       0.080
# C(year)[T.2012]               -0.4642      0.108     -4.293      0.000      -0.676      -0.252
# C(year)[T.2013]               -0.4880      0.108     -4.513      0.000      -0.700      -0.276
# C(year)[T.2014]               -0.4642      0.109     -4.263      0.000      -0.678      -0.250
# C(year)[T.2015]               -0.4592      0.109     -4.217      0.000      -0.673      -0.245
# C(year)[T.2016]               -0.3747      0.109     -3.441      0.001      -0.588      -0.161
# competition_allleg_lag         0.1989      0.047      4.249      0.000       0.107       0.291
# ==============================================================================
# Omnibus:                      120.920   Durbin-Watson:                   0.530
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              517.146
# Skew:                          -0.603   Prob(JB):                    5.05e-113
# Kurtosis:                       6.667   Cond. No.                         51.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Question 3.2. Now do the same for models 2 and 3 in table 1. Interpret the results of these three models.**

# %%
reg2 = smf.ols('democracy_mcmc ~ polarization_avg + C(state)+C(year)', data=df).fit()
reg2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         democracy_mcmc   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.649
# Method:                 Least Squares   F-statistic:                     24.64
# Date:                Fri, 10 Nov 2023   Prob (F-statistic):          1.37e-146
# Time:                        11:58:19   Log-Likelihood:                -633.77
# No. Observations:                 833   AIC:                             1400.
# Df Residuals:                     767   BIC:                             1711.
# Df Model:                          65
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.6832      0.158     -4.329      0.000      -0.993      -0.373
# C(state)[T.Alaska]             1.1693      0.185      6.315      0.000       0.806       1.533
# C(state)[T.Arizona]            1.0963      0.218      5.026      0.000       0.668       1.524
# C(state)[T.Arkansas]           0.6258      0.203      3.077      0.002       0.227       1.025
# C(state)[T.California]         1.9749      0.298      6.624      0.000       1.390       2.560
# C(state)[T.Colorado]           2.1091      0.252      8.366      0.000       1.614       2.604
# C(state)[T.Connecticut]        1.0532      0.185      5.690      0.000       0.690       1.417
# C(state)[T.Delaware]           0.7634      0.194      3.935      0.000       0.383       1.144
# C(state)[T.Florida]           -0.3692      0.187     -1.970      0.049      -0.737      -0.001
# C(state)[T.Georgia]           -0.0928      0.188     -0.493      0.622      -0.462       0.277
# C(state)[T.Hawaii]             1.3321      0.186      7.176      0.000       0.968       1.697
# C(state)[T.Idaho]              0.6469      0.194      3.336      0.001       0.266       1.028
# C(state)[T.Illinois]           1.4134      0.186      7.595      0.000       1.048       1.779
# C(state)[T.Indiana]            0.8151      0.185      4.404      0.000       0.452       1.179
# C(state)[T.Iowa]               1.5679      0.190      8.255      0.000       1.195       1.941
# C(state)[T.Kansas]             0.8366      0.185      4.516      0.000       0.473       1.200
# C(state)[T.Kentucky]           0.6339      0.185      3.425      0.001       0.271       0.997
# C(state)[T.Louisiana]          0.6101      0.208      2.935      0.003       0.202       1.018
# C(state)[T.Maine]              1.6763      0.190      8.842      0.000       1.304       2.048
# C(state)[T.Maryland]           1.2339      0.198      6.229      0.000       0.845       1.623
# C(state)[T.Massachusetts]      0.9868      0.187      5.277      0.000       0.620       1.354
# C(state)[T.Michigan]          -0.0847      0.205     -0.413      0.680      -0.487       0.318
# C(state)[T.Minnesota]          1.4946      0.199      7.500      0.000       1.103       1.886
# C(state)[T.Mississippi]        0.4663      0.186      2.504      0.012       0.101       0.832
# C(state)[T.Missouri]          -0.2699      0.196     -1.377      0.169      -0.655       0.115
# C(state)[T.Montana]            1.4630      0.197      7.409      0.000       1.075       1.851
# C(state)[T.Nevada]             1.0857      0.185      5.853      0.000       0.722       1.450
# C(state)[T.New Hampshire]      0.9585      0.200      4.798      0.000       0.566       1.351
# C(state)[T.New Jersey]         1.9697      0.191     10.288      0.000       1.594       2.346
# C(state)[T.New Mexico]         1.4739      0.201      7.346      0.000       1.080       1.868
# C(state)[T.New York]           1.3705      0.186      7.354      0.000       1.005       1.736
# C(state)[T.North Carolina]     0.8590      0.187      4.589      0.000       0.492       1.227
# C(state)[T.North Dakota]       1.4168      0.187      7.571      0.000       1.049       1.784
# C(state)[T.Ohio]               0.1076      0.194      0.554      0.580      -0.273       0.489
# C(state)[T.Oklahoma]           0.7439      0.186      4.005      0.000       0.379       1.108
# C(state)[T.Oregon]             1.7351      0.191      9.103      0.000       1.361       2.109
# C(state)[T.Pennsylvania]       0.4617      0.185      2.492      0.013       0.098       0.825
# C(state)[T.Rhode Island]       0.9088      0.215      4.229      0.000       0.487       1.331
# C(state)[T.South Carolina]    -1.4519      0.186     -7.820      0.000      -1.816      -1.087
# C(state)[T.South Dakota]       1.1173      0.189      5.924      0.000       0.747       1.487
# C(state)[T.Tennessee]         -0.1768      0.185     -0.955      0.340      -0.540       0.187
# C(state)[T.Texas]              0.4956      0.213      2.322      0.020       0.077       0.915
# C(state)[T.Utah]               0.8694      0.191      4.558      0.000       0.495       1.244
# C(state)[T.Vermont]            1.2154      0.185      6.566      0.000       0.852       1.579
# C(state)[T.Virginia]           0.0325      0.188      0.172      0.863      -0.337       0.402
# C(state)[T.Washington]         2.4357      0.223     10.938      0.000       1.999       2.873
# C(state)[T.West Virginia]      0.8396      0.191      4.395      0.000       0.465       1.215
# C(state)[T.Wisconsin]          1.0986      0.203      5.408      0.000       0.700       1.497
# C(state)[T.Wyoming]            1.1445      0.186      6.162      0.000       0.780       1.509
# C(year)[T.2001]                0.0076      0.109      0.070      0.944      -0.207       0.222
# C(year)[T.2002]               -0.0098      0.109     -0.090      0.928      -0.224       0.204
# C(year)[T.2003]               -0.0093      0.109     -0.085      0.933      -0.224       0.206
# C(year)[T.2004]               -0.1072      0.110     -0.979      0.328      -0.322       0.108
# C(year)[T.2005]               -0.1172      0.110     -1.066      0.287      -0.333       0.099
# C(year)[T.2006]               -0.0756      0.110     -0.688      0.492      -0.291       0.140
# C(year)[T.2007]               -0.0776      0.110     -0.702      0.483      -0.294       0.139
# C(year)[T.2008]               -0.0310      0.111     -0.280      0.779      -0.248       0.186
# C(year)[T.2009]               -0.0260      0.112     -0.232      0.817      -0.247       0.195
# C(year)[T.2010]               -0.1297      0.112     -1.155      0.248      -0.350       0.091
# C(year)[T.2011]               -0.1556      0.115     -1.355      0.176      -0.381       0.070
# C(year)[T.2012]               -0.5093      0.116     -4.404      0.000      -0.736      -0.282
# C(year)[T.2013]               -0.5339      0.117     -4.563      0.000      -0.764      -0.304
# C(year)[T.2014]               -0.5389      0.117     -4.598      0.000      -0.769      -0.309
# C(year)[T.2015]               -0.5347      0.119     -4.501      0.000      -0.768      -0.301
# C(year)[T.2016]               -0.4514      0.121     -3.724      0.000      -0.689      -0.213
# polarization_avg               0.0145      0.074      0.196      0.845      -0.131       0.160
# ==============================================================================
# Omnibus:                      120.378   Durbin-Watson:                   0.533
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              497.431
# Skew:                          -0.610   Prob(JB):                    9.64e-109
# Kurtosis:                       6.583   Cond. No.                         52.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
reg3 = smf.ols('democracy_mcmc ~ Republican + C(state)+C(year)', data=df).fit()
reg3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         democracy_mcmc   R-squared:                       0.699
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     27.45
# Date:                Fri, 10 Nov 2023   Prob (F-statistic):          1.76e-158
# Time:                        11:58:42   Log-Likelihood:                -602.89
# No. Observations:                 833   AIC:                             1338.
# Df Residuals:                     767   BIC:                             1650.
# Df Model:                          65
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.5321      0.147     -3.626      0.000      -0.820      -0.244
# C(state)[T.Alaska]             1.2242      0.178      6.858      0.000       0.874       1.575
# C(state)[T.Arizona]            1.1998      0.179      6.715      0.000       0.849       1.551
# C(state)[T.Arkansas]           0.5014      0.179      2.802      0.005       0.150       0.853
# C(state)[T.California]         1.8588      0.180     10.350      0.000       1.506       2.211
# C(state)[T.Colorado]           2.0617      0.179     11.539      0.000       1.711       2.412
# C(state)[T.Connecticut]        0.8917      0.180      4.965      0.000       0.539       1.244
# C(state)[T.Delaware]           0.5901      0.180      3.286      0.001       0.238       0.943
# C(state)[T.Florida]           -0.0666      0.182     -0.365      0.715      -0.425       0.292
# C(state)[T.Georgia]            0.0759      0.180      0.422      0.673      -0.277       0.428
# C(state)[T.Hawaii]             1.1674      0.180      6.500      0.000       0.815       1.520
# C(state)[T.Idaho]              0.9550      0.182      5.233      0.000       0.597       1.313
# C(state)[T.Illinois]           1.2477      0.180      6.947      0.000       0.895       1.600
# C(state)[T.Indiana]            0.8688      0.178      4.867      0.000       0.518       1.219
# C(state)[T.Iowa]               1.4144      0.180      7.875      0.000       1.062       1.767
# C(state)[T.Kansas]             0.9191      0.179      5.144      0.000       0.568       1.270
# C(state)[T.Kentucky]           0.4719      0.180      2.628      0.009       0.119       0.824
# C(state)[T.Louisiana]          0.5646      0.178      3.165      0.002       0.214       0.915
# C(state)[T.Maine]              1.5764      0.179      8.811      0.000       1.225       1.928
# C(state)[T.Maryland]           1.0858      0.180      6.046      0.000       0.733       1.438
# C(state)[T.Massachusetts]      0.8196      0.180      4.564      0.000       0.467       1.172
# C(state)[T.Michigan]           0.0136      0.179      0.076      0.939      -0.337       0.364
# C(state)[T.Minnesota]          1.3472      0.180      7.501      0.000       0.995       1.700
# C(state)[T.Mississippi]        0.4354      0.178      2.440      0.015       0.085       0.786
# C(state)[T.Missouri]          -0.3113      0.178     -1.744      0.082      -0.662       0.039
# C(state)[T.Montana]            1.4495      0.178      8.125      0.000       1.099       1.800
# C(state)[T.Nevada]             0.9754      0.179      5.452      0.000       0.624       1.327
# C(state)[T.New Hampshire]      0.8653      0.179      4.836      0.000       0.514       1.217
# C(state)[T.New Jersey]         1.8522      0.179     10.352      0.000       1.501       2.203
# C(state)[T.New Mexico]         1.3272      0.180      7.390      0.000       0.975       1.680
# C(state)[T.New York]           1.2128      0.180      6.753      0.000       0.860       1.565
# C(state)[T.North Carolina]     0.8105      0.178      4.541      0.000       0.460       1.161
# C(state)[T.North Dakota]       1.7082      0.182      9.360      0.000       1.350       2.066
# C(state)[T.Ohio]               0.3079      0.180      1.710      0.088      -0.046       0.661
# C(state)[T.Oklahoma]           0.7409      0.178      4.154      0.000       0.391       1.091
# C(state)[T.Oregon]             1.5821      0.180      8.809      0.000       1.230       1.935
# C(state)[T.Pennsylvania]       0.4871      0.178      2.730      0.006       0.137       0.837
# C(state)[T.Rhode Island]       0.7255      0.180      4.040      0.000       0.373       1.078
# C(state)[T.South Carolina]    -1.2389      0.181     -6.861      0.000      -1.593      -0.884
# C(state)[T.South Dakota]       1.4070      0.182      7.710      0.000       1.049       1.765
# C(state)[T.Tennessee]         -0.1756      0.178     -0.984      0.325      -0.526       0.175
# C(state)[T.Texas]              0.7323      0.181      4.056      0.000       0.378       1.087
# C(state)[T.Utah]               1.1752      0.182      6.440      0.000       0.817       1.533
# C(state)[T.Vermont]            1.0534      0.180      5.865      0.000       0.701       1.406
# C(state)[T.Virginia]          -0.0687      0.179     -0.384      0.701      -0.420       0.282
# C(state)[T.Washington]         2.2980      0.180     12.795      0.000       1.945       2.651
# C(state)[T.West Virginia]      0.6684      0.180      3.722      0.000       0.316       1.021
# C(state)[T.Wisconsin]          1.0880      0.178      6.099      0.000       0.738       1.438
# C(state)[T.Wyoming]            1.2224      0.179      6.842      0.000       0.872       1.573
# C(year)[T.2001]               -0.0104      0.105     -0.099      0.921      -0.217       0.196
# C(year)[T.2002]               -0.0465      0.105     -0.442      0.659      -0.253       0.160
# C(year)[T.2003]               -0.0354      0.105     -0.337      0.737      -0.242       0.171
# C(year)[T.2004]               -0.1332      0.105     -1.267      0.205      -0.340       0.073
# C(year)[T.2005]               -0.1426      0.105     -1.356      0.175      -0.349       0.064
# C(year)[T.2006]               -0.1010      0.105     -0.960      0.337      -0.307       0.105
# C(year)[T.2007]               -0.1209      0.105     -1.149      0.251      -0.327       0.086
# C(year)[T.2008]               -0.0742      0.105     -0.705      0.481      -0.281       0.132
# C(year)[T.2009]               -0.0769      0.105     -0.730      0.466      -0.284       0.130
# C(year)[T.2010]               -0.1806      0.105     -1.715      0.087      -0.387       0.026
# C(year)[T.2011]               -0.1017      0.105     -0.967      0.334      -0.308       0.105
# C(year)[T.2012]               -0.4456      0.105     -4.231      0.000      -0.652      -0.239
# C(year)[T.2013]               -0.4507      0.106     -4.272      0.000      -0.658      -0.244
# C(year)[T.2014]               -0.4556      0.106     -4.318      0.000      -0.663      -0.248
# C(year)[T.2015]               -0.4506      0.106     -4.270      0.000      -0.658      -0.243
# C(year)[T.2016]               -0.3661      0.106     -3.470      0.001      -0.573      -0.159
# Republican                    -0.4587      0.060     -7.686      0.000      -0.576      -0.342
# ==============================================================================
# Omnibus:                       96.306   Durbin-Watson:                   0.616
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              352.565
# Skew:                          -0.502   Prob(JB):                     2.76e-77
# Kurtosis:                       6.025   Cond. No.                         54.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Question 3.3. Now replicate the model in column 7, where "Competition x Republican" is an interaction term between these two variables. Suppose that hypothetically the Coefficient on Competition X Republican was around .475 (i.e., the same as the Competition coefficient but positive): what would this mean how the relationship between close elections, party control, and levels of democracy?**

# %%
reg7 = smf.ols('democracy_mcmc ~ competition_allleg_lag + polarization_avg + Republican + Republican*competition_allleg_lag + C(state)+C(year)', data=df).fit()
reg7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         democracy_mcmc   R-squared:                       0.706
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     26.94
# Date:                Wed, 01 Nov 2023   Prob (F-statistic):          1.02e-159
# Time:                        09:39:10   Log-Likelihood:                -594.05
# No. Observations:                 833   AIC:                             1326.
# Df Residuals:                     764   BIC:                             1652.
# Df Model:                          68
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -0.5337      0.153     -3.494      0.001      -0.834      -0.234
# C(state)[T.Alaska]                    1.2215      0.177      6.890      0.000       0.874       1.570
# C(state)[T.Arizona]                   1.1222      0.209      5.381      0.000       0.713       1.532
# C(state)[T.Arkansas]                  0.6112      0.197      3.103      0.002       0.225       0.998
# C(state)[T.California]                1.7893      0.288      6.219      0.000       1.225       2.354
# C(state)[T.Colorado]                  1.8762      0.243      7.722      0.000       1.399       2.353
# C(state)[T.Connecticut]               0.9128      0.178      5.118      0.000       0.563       1.263
# C(state)[T.Delaware]                  0.5316      0.189      2.809      0.005       0.160       0.903
# C(state)[T.Florida]                   0.0067      0.186      0.036      0.971      -0.358       0.372
# C(state)[T.Georgia]                  -0.0010      0.182     -0.005      0.996      -0.358       0.356
# C(state)[T.Hawaii]                    1.4680      0.212      6.924      0.000       1.052       1.884
# C(state)[T.Idaho]                     1.4156      0.237      5.985      0.000       0.951       1.880
# C(state)[T.Illinois]                  1.1720      0.182      6.448      0.000       0.815       1.529
# C(state)[T.Indiana]                   0.8619      0.179      4.826      0.000       0.511       1.212
# C(state)[T.Iowa]                      1.2813      0.187      6.837      0.000       0.913       1.649
# C(state)[T.Kansas]                    1.1042      0.184      6.007      0.000       0.743       1.465
# C(state)[T.Kentucky]                  0.3402      0.185      1.840      0.066      -0.023       0.703
# C(state)[T.Louisiana]                 0.5360      0.200      2.684      0.007       0.144       0.928
# C(state)[T.Maine]                     1.4270      0.187      7.648      0.000       1.061       1.793
# C(state)[T.Maryland]                  1.1834      0.198      5.967      0.000       0.794       1.573
# C(state)[T.Massachusetts]             1.1557      0.219      5.273      0.000       0.725       1.586
# C(state)[T.Michigan]                 -0.1154      0.197     -0.584      0.559      -0.503       0.272
# C(state)[T.Minnesota]                 1.2042      0.196      6.154      0.000       0.820       1.588
# C(state)[T.Mississippi]               0.3602      0.179      2.010      0.045       0.008       0.712
# C(state)[T.Missouri]                 -0.3606      0.188     -1.923      0.055      -0.729       0.008
# C(state)[T.Montana]                   1.3214      0.191      6.921      0.000       0.947       1.696
# C(state)[T.Nevada]                    0.8676      0.182      4.758      0.000       0.510       1.226
# C(state)[T.New Hampshire]             0.7819      0.193      4.062      0.000       0.404       1.160
# C(state)[T.New Jersey]                1.7791      0.186      9.553      0.000       1.414       2.145
# C(state)[T.New Mexico]                1.2524      0.194      6.470      0.000       0.872       1.632
# C(state)[T.New York]                  1.1352      0.181      6.273      0.000       0.780       1.491
# C(state)[T.North Carolina]            0.7281      0.181      4.028      0.000       0.373       1.083
# C(state)[T.North Dakota]              1.8580      0.190      9.797      0.000       1.486       2.230
# C(state)[T.Ohio]                      0.2900      0.187      1.549      0.122      -0.077       0.658
# C(state)[T.Oklahoma]                  0.7334      0.180      4.071      0.000       0.380       1.087
# C(state)[T.Oregon]                    1.4525      0.188      7.741      0.000       1.084       1.821
# C(state)[T.Pennsylvania]              0.3580      0.181      1.980      0.048       0.003       0.713
# C(state)[T.Rhode Island]              1.0892      0.237      4.587      0.000       0.623       1.555
# C(state)[T.South Carolina]           -1.3374      0.182     -7.347      0.000      -1.695      -0.980
# C(state)[T.South Dakota]              1.6529      0.199      8.312      0.000       1.263       2.043
# C(state)[T.Tennessee]                -0.2214      0.180     -1.229      0.219      -0.575       0.132
# C(state)[T.Texas]                     0.6180      0.206      3.004      0.003       0.214       1.022
# C(state)[T.Utah]                      1.4666      0.208      7.035      0.000       1.057       1.876
# C(state)[T.Vermont]                   1.0755      0.178      6.031      0.000       0.725       1.426
# C(state)[T.Virginia]                 -0.1747      0.183     -0.956      0.339      -0.533       0.184
# C(state)[T.Washington]                2.1611      0.216     10.012      0.000       1.737       2.585
# C(state)[T.West Virginia]             0.8036      0.189      4.263      0.000       0.434       1.174
# C(state)[T.Wisconsin]                 0.9294      0.197      4.717      0.000       0.543       1.316
# C(state)[T.Wyoming]                   1.5300      0.193      7.911      0.000       1.150       1.910
# C(year)[T.2001]                      -0.0095      0.104     -0.091      0.928      -0.214       0.195
# C(year)[T.2002]                      -0.0428      0.104     -0.410      0.682      -0.248       0.162
# C(year)[T.2003]                      -0.0385      0.105     -0.368      0.713      -0.244       0.167
# C(year)[T.2004]                      -0.1393      0.105     -1.330      0.184      -0.345       0.066
# C(year)[T.2005]                      -0.1512      0.105     -1.439      0.150      -0.358       0.055
# C(year)[T.2006]                      -0.1091      0.105     -1.038      0.299      -0.315       0.097
# C(year)[T.2007]                      -0.1296      0.106     -1.225      0.221      -0.337       0.078
# C(year)[T.2008]                      -0.0758      0.106     -0.715      0.475      -0.284       0.132
# C(year)[T.2009]                      -0.0815      0.108     -0.756      0.450      -0.293       0.130
# C(year)[T.2010]                      -0.1767      0.108     -1.638      0.102      -0.388       0.035
# C(year)[T.2011]                      -0.1070      0.110     -0.972      0.331      -0.323       0.109
# C(year)[T.2012]                      -0.4274      0.111     -3.846      0.000      -0.646      -0.209
# C(year)[T.2013]                      -0.4364      0.113     -3.877      0.000      -0.657      -0.215
# C(year)[T.2014]                      -0.4014      0.114     -3.523      0.000      -0.625      -0.178
# C(year)[T.2015]                      -0.3985      0.115     -3.453      0.001      -0.625      -0.172
# C(year)[T.2016]                      -0.3161      0.118     -2.685      0.007      -0.547      -0.085
# competition_allleg_lag                0.1334      0.052      2.589      0.010       0.032       0.235
# polarization_avg                      0.0251      0.071      0.352      0.725      -0.115       0.165
# Republican                           -0.4711      0.063     -7.493      0.000      -0.595      -0.348
# Republican:competition_allleg_lag     0.1106      0.074      1.486      0.138      -0.035       0.257
# ==============================================================================
# Omnibus:                      102.570   Durbin-Watson:                   0.602
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              388.731
# Skew:                          -0.530   Prob(JB):                     3.87e-85
# Kurtosis:                       6.174   Cond. No.                         56.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# If the coefficient on the interaction term was around .475 this would mean that having Republican control only decreases levels of democracy in the absence of political competition.

# %% [markdown]
# **Question 3.4. Finally, replicate model 4 in table 2. Note the relevant variables to add are pct_black_change and pct_latino_change. Interpret the coefficients on these variables.**

# %%
reg8 = smf.ols('democracy_mcmc ~ + pct_black_change + pct_latino_change + C(state)+C(year)', data=df).fit()
reg8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         democracy_mcmc   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.648
# Method:                 Least Squares   F-statistic:                     24.24
# Date:                Wed, 01 Nov 2023   Prob (F-statistic):          6.77e-146
# Time:                        09:39:14   Log-Likelihood:                -633.76
# No. Observations:                 833   AIC:                             1402.
# Df Residuals:                     766   BIC:                             1718.
# Df Model:                          66
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.6773      0.165     -4.105      0.000      -1.001      -0.353
# C(state)[T.Alaska]             1.1707      0.186      6.300      0.000       0.806       1.536
# C(state)[T.Arizona]            1.1361      0.199      5.704      0.000       0.745       1.527
# C(state)[T.Arkansas]           0.6159      0.190      3.241      0.001       0.243       0.989
# C(state)[T.California]         2.0376      0.205      9.947      0.000       1.636       2.440
# C(state)[T.Colorado]           2.1522      0.190     11.344      0.000       1.780       2.525
# C(state)[T.Connecticut]        1.0683      0.198      5.391      0.000       0.679       1.457
# C(state)[T.Delaware]           0.7615      0.210      3.620      0.000       0.349       1.174
# C(state)[T.Florida]           -0.3393      0.212     -1.601      0.110      -0.755       0.077
# C(state)[T.Georgia]           -0.0754      0.206     -0.366      0.714      -0.480       0.329
# C(state)[T.Hawaii]             1.3284      0.187      7.098      0.000       0.961       1.696
# C(state)[T.Idaho]              0.6660      0.189      3.529      0.000       0.296       1.037
# C(state)[T.Illinois]           1.4188      0.195      7.290      0.000       1.037       1.801
# C(state)[T.Indiana]            0.8184      0.187      4.379      0.000       0.452       1.185
# C(state)[T.Iowa]               1.5794      0.188      8.418      0.000       1.211       1.948
# C(state)[T.Kansas]             0.8481      0.190      4.466      0.000       0.475       1.221
# C(state)[T.Kentucky]           0.6323      0.186      3.407      0.001       0.268       0.997
# C(state)[T.Louisiana]          0.5900      0.186      3.174      0.002       0.225       0.955
# C(state)[T.Maine]              1.6768      0.188      8.920      0.000       1.308       2.046
# C(state)[T.Maryland]           1.2595      0.203      6.209      0.000       0.861       1.658
# C(state)[T.Massachusetts]      0.9901      0.194      5.097      0.000       0.609       1.371
# C(state)[T.Michigan]          -0.0713      0.187     -0.381      0.703      -0.438       0.296
# C(state)[T.Minnesota]          1.5105      0.198      7.628      0.000       1.122       1.899
# C(state)[T.Mississippi]        0.4595      0.186      2.470      0.014       0.094       0.825
# C(state)[T.Missouri]          -0.2599      0.186     -1.401      0.162      -0.624       0.104
# C(state)[T.Montana]            1.4721      0.187      7.886      0.000       1.106       1.839
# C(state)[T.Nevada]             1.1152      0.231      4.817      0.000       0.661       1.570
# C(state)[T.New Hampshire]      0.9695      0.186      5.216      0.000       0.605       1.334
# C(state)[T.New Jersey]         1.9752      0.196     10.080      0.000       1.591       2.360
# C(state)[T.New Mexico]         1.5048      0.197      7.622      0.000       1.117       1.892
# C(state)[T.New York]           1.3791      0.187      7.364      0.000       1.011       1.747
# C(state)[T.North Carolina]     0.8747      0.191      4.588      0.000       0.500       1.249
# C(state)[T.North Dakota]       1.4101      0.189      7.473      0.000       1.040       1.780
# C(state)[T.Ohio]               0.1156      0.187      0.617      0.538      -0.252       0.484
# C(state)[T.Oklahoma]           0.7512      0.190      3.943      0.000       0.377       1.125
# C(state)[T.Oregon]             1.7543      0.191      9.202      0.000       1.380       2.128
# C(state)[T.Pennsylvania]       0.4646      0.189      2.462      0.014       0.094       0.835
# C(state)[T.Rhode Island]       0.9041      0.206      4.391      0.000       0.500       1.308
# C(state)[T.South Carolina]    -1.4538      0.206     -7.041      0.000      -1.859      -1.048
# C(state)[T.South Dakota]       1.1097      0.186      5.957      0.000       0.744       1.475
# C(state)[T.Tennessee]         -0.1731      0.186     -0.933      0.351      -0.537       0.191
# C(state)[T.Texas]              0.5372      0.205      2.622      0.009       0.135       0.939
# C(state)[T.Utah]               0.8891      0.191      4.654      0.000       0.514       1.264
# C(state)[T.Vermont]            1.2081      0.188      6.440      0.000       0.840       1.576
# C(state)[T.Virginia]           0.0465      0.189      0.246      0.806      -0.324       0.417
# C(state)[T.Washington]         2.4701      0.190     13.007      0.000       2.097       2.843
# C(state)[T.West Virginia]      0.8228      0.188      4.378      0.000       0.454       1.192
# C(state)[T.Wisconsin]          1.1173      0.186      6.017      0.000       0.753       1.482
# C(state)[T.Wyoming]            1.1445      0.186      6.161      0.000       0.780       1.509
# C(year)[T.2001]                0.0085      0.109      0.078      0.938      -0.206       0.223
# C(year)[T.2002]               -0.0088      0.109     -0.081      0.936      -0.223       0.205
# C(year)[T.2003]               -0.0076      0.109     -0.069      0.945      -0.222       0.207
# C(year)[T.2004]               -0.1070      0.109     -0.978      0.328      -0.322       0.108
# C(year)[T.2005]               -0.1165      0.109     -1.065      0.287      -0.331       0.098
# C(year)[T.2006]               -0.0749      0.109     -0.684      0.494      -0.290       0.140
# C(year)[T.2007]               -0.0756      0.109     -0.692      0.489      -0.290       0.139
# C(year)[T.2008]               -0.0286      0.109     -0.261      0.794      -0.243       0.186
# C(year)[T.2009]               -0.0222      0.109     -0.203      0.839      -0.237       0.192
# C(year)[T.2010]               -0.1271      0.110     -1.158      0.247      -0.342       0.088
# C(year)[T.2011]               -0.1531      0.111     -1.382      0.168      -0.371       0.064
# C(year)[T.2012]               -0.5081      0.112     -4.522      0.000      -0.729      -0.287
# C(year)[T.2013]               -0.5333      0.114     -4.682      0.000      -0.757      -0.310
# C(year)[T.2014]               -0.5391      0.115     -4.688      0.000      -0.765      -0.313
# C(year)[T.2015]               -0.5341      0.115     -4.641      0.000      -0.760      -0.308
# C(year)[T.2016]               -0.4495      0.115     -3.913      0.000      -0.675      -0.224
# pct_black_change              -0.0030      0.133     -0.023      0.982      -0.264       0.258
# pct_latino_change             -0.0161      0.067     -0.240      0.810      -0.148       0.116
# ==============================================================================
# Omnibus:                      122.188   Durbin-Watson:                   0.532
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              507.719
# Skew:                          -0.619   Prob(JB):                    5.63e-111
# Kurtosis:                       6.618   Cond. No.                         78.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Question 3.5. All of the analysis here compares Republican control to divided or Democratic control. Run a regression similar to those above but which also can answer the question of whether there is a meaningful difference between divided government and unified Democratic state government.**
