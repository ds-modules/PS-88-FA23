# %% [markdown]
# # PS 88 - Lab 13 - DiD and Fixed Effects

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Part 1: Propaganda News
#
# Let's explore a simulated example of media persuasion with more than two time periods and more than two people.
#
# Suppose the president of a semi-democratic country tries to increase his grip on power by helping create Propaganda News Channel (PNC). The president was gradually increasing his popularity over time, and PNC was introduced 5 years into his term. Suppose the managers of the station also generally targeted regions with more people who support the president to get higher viewership.
#
# As we will see, this creates multiple sources of selection bias in trying to estimate the causal effect of PNC, but the one-two punch of two-way fixed effects will knock all of them out.
#
# We will study some hypothetical survey data, collected over 10 years (2000-2009). Each respondent lives in one of four regions, which we label 1-4. Citizens in "higher" regions tend to like the president more. Our key outcome variable will be the approval rating of the president, which ranges from 0 to 100.
#
# PNC is available in regions 3 and 4 starting in 2006.
#
# The simulation generates the potential outcomes of approval without access to PNC, and then adds the true causal effect (a 5 point approval boost) to those where PNC is available.

# %%
# True causal effect
np.random.seed(88)
k=5
yr = np.random.randint(2000,2010, 100000)
region = np.random.randint(1,5, size=100000)
approve0 = 60*np.random.rand(100000) + 2*np.sqrt(yr - 2000) +2*region**2
avail = 1*(region > 2)*(yr > 2005)
approve = np.where(avail==1, approve0 + k, approve0)
pncdata = pd.DataFrame({"Year":yr, "Region": region, "Available":avail, "Approve":approve})
#pncdata = pd.DataFrame({"Year":yr, "Region": region, "Available":avail, "Watch":watch, "Approve":approve})
pncdata
# Out:
#        Year  Region  Available    Approve
# 0      2008       2          0  19.095789
# 1      2000       1          0  10.176033
# 2      2001       3          0  56.116278
# 3      2004       3          0  57.125248
# 4      2005       3          0  61.316645
# ...     ...     ...        ...        ...
# 99995  2002       3          0  41.300125
# 99996  2002       3          0  29.461023
# 99997  2007       4          1  95.476132
# 99998  2000       1          0  54.677766
# 99999  2007       1          0  10.064052
#
# [100000 rows x 4 columns]

# %% [markdown]
# To check the simulation did what we want and get some practice with exploring the data, let's look at a crosstab (like a pivot table) that counts how many respondents there are by `Year` and `Available`. We can do this with `pd.crosstab`, where we input as arguments two columns, and the output is a count of how many cases take on each combination of values of the two columns:

# %%
pd.crosstab(pncdata['Year'],pncdata['Available'])
# Out:
# Available      0     1
# Year
# 2000       10053     0
# 2001       10095     0
# 2002       10012     0
# 2003       10060     0
# 2004        9724     0
# 2005       10025     0
# 2006        5043  5033
# 2007        4807  4994
# 2008        5015  5145
# 2009        5135  4859

# %% [markdown]
# **Question 1.1 Create a crosstab that counts how many had respondents had PNC available by region**

# %%
# Code for 1.1
pd.crosstab(pncdata['Region'],pncdata['Available'])
# Out:
# Available      0      1
# Region
# 1          24806      0
# 2          25076      0
# 3          14958   9980
# 4          15129  10051

# %% [markdown]
# We can plot the overall approval over time with `sns.lineplot`.

# %%
sns.lineplot(x='Year', y='Approve', data=pncdata, ci=None)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Approve'>

# %% [markdown]
# Clearly this is trending up. Since the station was rolled out later in the time window, this might create confounding as those who have access to PNC will be in the later years.
#
# We can also compute the average approval by region using the `groupby` function`.

# %%
pncdata.groupby("Region")['Approve'].mean()
# Out:
# Region
# 1    35.594925
# 2    41.854961
# 3    54.036815
# 4    68.004375
# Name: Approve, dtype: float64

# %% [markdown]
# There are big differences here, with approval much higher in the regions that got PNC (3 and 4). But this might be because the president is just more popular there in general.

# %% [markdown]
# What is the average approval for people with access to PNC vs. not? To facilitate later comparisons, let's use `smf.ols` to run a linear regression to answer this.

# %%
smf.ols('Approve ~ Available', data=pncdata).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Approve   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                 1.544e+04
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:53:21   Log-Likelihood:            -4.4150e+05
# No. Observations:              100000   AIC:                         8.830e+05
# Df Residuals:                   99998   BIC:                         8.830e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     45.9896      0.071    650.074      0.000      45.851      46.128
# Available     19.6435      0.158    124.272      0.000      19.334      19.953
# ==============================================================================
# Omnibus:                     5975.864   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2295.201
# Skew:                           0.088   Prob(JB):                         0.00
# Kurtosis:                       2.279   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The available coefficient tells us that approval of the president is much higher among those with access to PNC, and this difference is much bigger than the real causal effect of 5.

# %% [markdown]
# Now let's add some "region fixed effects". Since our region variable is numeric, there is nothing technically wrong with running the following regression:

# %%
smf.ols('Approve ~ Available + Region', data=pncdata).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Approve   R-squared:                       0.340
# Model:                            OLS   Adj. R-squared:                  0.340
# Method:                 Least Squares   F-statistic:                 2.575e+04
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:52:28   Log-Likelihood:            -4.2791e+05
# No. Observations:              100000   AIC:                         8.558e+05
# Df Residuals:                   99997   BIC:                         8.559e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     23.9897      0.139    172.618      0.000      23.717      24.262
# Available      7.4833      0.154     48.532      0.000       7.181       7.786
# Region         9.7551      0.055    176.707      0.000       9.647       9.863
# ==============================================================================
# Omnibus:                    58545.341   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5511.550
# Skew:                          -0.003   Prob(JB):                         0.00
# Kurtosis:                       1.850   Cond. No.                         8.92
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# This tells us that as the region goes up by "one unit", approval goes up by about 10%. But going up by one unit could correspond to going from region 1 to 2, 2 to 3, or 3 to 4. And there is no reason to think that all of these changes similar. If we want to add fixed effects, we need to add a `C()` around the Region variable in our regression formula.

# %%
smf.ols('Approve ~ Available + C(Region)', data=pncdata).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Approve   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.348
# Method:                 Least Squares   F-statistic:                 1.335e+04
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:52:38   Log-Likelihood:            -4.2729e+05
# No. Observations:              100000   AIC:                         8.546e+05
# Df Residuals:                   99995   BIC:                         8.546e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         35.5949      0.110    323.006      0.000      35.379      35.811
# C(Region)[T.2]     6.2600      0.155     40.277      0.000       5.955       6.565
# C(Region)[T.3]    15.3835      0.168     91.550      0.000      15.054      15.713
# C(Region)[T.4]    29.3589      0.168    175.145      0.000      29.030      29.687
# Available          7.6423      0.158     48.285      0.000       7.332       7.952
# ==============================================================================
# Omnibus:                    74885.081   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5812.034
# Skew:                          -0.006   Prob(JB):                         0.00
# Kurtosis:                       1.819   Cond. No.                         5.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The output is a bit goofy, but we can see that it is creating dummy variabels for regions 2, 3, and 4 (not sure what the T is about here). Since region 1 doesn't have a dummy variable, it is the *reference category*. The coefficient on `C(Region)[T.2]` tells us how much higher the approval is in region 2 vs region 1, on average, keeping fixed all other variables. The coefficients on the other regions are how much higher (or lower) the approval is compared to the referent category of region 1.
#
# Note the coefficient on `Available` goes down when we add the region fixed effects. This means that a lot of the difference in average approval among those with access to PNC vs not was driven by the fact that it was only available in regions that already liked the president.

# %% [markdown]
# **Question 1.2. Fit and summarize a regression predicting Approval with `Available` and the year fixed effects (but no region fixed effects). How does the estimate of the effect of PNC compare to the real causal effect of 5?**

# %%
# Code for 1.2
smf.ols('Approve ~ Available + C(Year)', data=pncdata).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Approve   R-squared:                       0.156
# Model:                            OLS   Adj. R-squared:                  0.156
# Method:                 Least Squares   F-statistic:                     1842.
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):               0.00
# Time:                        17:29:12   Log-Likelihood:            -4.4022e+05
# No. Observations:              100000   AIC:                         8.805e+05
# Df Residuals:                   99989   BIC:                         8.806e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          45.2389      0.197    229.626      0.000      44.853      45.625
# C(Year)[T.2001]     1.8419      0.278      6.618      0.000       1.296       2.387
# C(Year)[T.2002]     2.7299      0.279      9.788      0.000       2.183       3.277
# C(Year)[T.2003]     3.4352      0.279     12.332      0.000       2.889       3.981
# C(Year)[T.2004]     3.8418      0.281     13.674      0.000       3.291       4.392
# C(Year)[T.2005]     4.1867      0.279     15.016      0.000       3.640       4.733
# C(Year)[T.2006]    -5.5678      0.295    -18.847      0.000      -6.147      -4.989
# C(Year)[T.2007]    -5.1922      0.298    -17.429      0.000      -5.776      -4.608
# C(Year)[T.2008]    -4.9015      0.295    -16.597      0.000      -5.480      -4.323
# C(Year)[T.2009]    -4.3159      0.295    -14.626      0.000      -4.894      -3.738
# Available          25.3936      0.197    128.583      0.000      25.006      25.781
# ==============================================================================
# Omnibus:                     6891.384   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2401.163
# Skew:                           0.040   Prob(JB):                         0.00
# Kurtosis:                       2.245   Cond. No.                         11.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Here the coefficient on Available is about 25, much higher than the real causal effect.
#
# (This is a more subtle point, but note that in this example only using year fixed effects leads to an even more incorrect answer! )

# %% [markdown]
# **Question 1.3. Now run a regression predicting Approval with `Available`, the year fixed effects, and the region fixed effects. Does this produce an estimate close to the real casual effect of 5?**

# %%
# Code for 1.3
smf.ols('Approve ~ Available + C(Region) + C(Year)', data=pncdata).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Approve   R-squared:                       0.352
# Model:                            OLS   Adj. R-squared:                  0.352
# Method:                 Least Squares   F-statistic:                     4184.
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):               0.00
# Time:                        17:29:14   Log-Likelihood:            -4.2696e+05
# No. Observations:              100000   AIC:                         8.539e+05
# Df Residuals:                   99986   BIC:                         8.541e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          31.9941      0.202    158.656      0.000      31.599      32.389
# C(Region)[T.2]      6.2467      0.155     40.320      0.000       5.943       6.550
# C(Region)[T.3]     16.3550      0.179     91.361      0.000      16.004      16.706
# C(Region)[T.4]     30.3463      0.179    169.887      0.000      29.996      30.696
# C(Year)[T.2001]     1.8000      0.244      7.384      0.000       1.322       2.278
# C(Year)[T.2002]     2.7096      0.244     11.093      0.000       2.231       3.188
# C(Year)[T.2003]     3.3302      0.244     13.650      0.000       2.852       3.808
# C(Year)[T.2004]     3.8952      0.246     15.830      0.000       3.413       4.378
# C(Year)[T.2005]     3.9937      0.244     16.354      0.000       3.515       4.472
# C(Year)[T.2006]     4.6399      0.268     17.312      0.000       4.115       5.165
# C(Year)[T.2007]     4.7892      0.270     17.730      0.000       4.260       5.319
# C(Year)[T.2008]     5.1980      0.268     19.400      0.000       4.673       5.723
# C(Year)[T.2009]     5.7678      0.268     21.544      0.000       5.243       6.293
# Available           5.1696      0.223     23.147      0.000       4.732       5.607
# ==============================================================================
# Omnibus:                    88184.412   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5994.715
# Skew:                          -0.005   Prob(JB):                         0.00
# Kurtosis:                       1.801   Cond. No.                         12.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Now the coefficient on Available is about 5.17, close to the truth of 5. This is because once we account for the time trend and regional bias we are able to isolate the causal effect of PNC availability.

# %% [markdown]
# This method can also work even if there isn't just a single time period where one group gets the treatment.
#
# Here is some alternative simulated data about ("Lame Propaganda News Channel") in a different country, which contains bad propaganda which actually lowers approval by one unit.  LPNC is "rolled out" by region, first going to region 4, then 3, then 2, then 1.
#
# For this simulation, we will assume that the real causal effect of LPNC availability is to *decrease* approval by one unit.

# %%
np.random.seed(8888)
avail2 = 1*(region + yr > 2006)
approve2 = np.where(avail2==1, approve0 -1, approve0)
lpncdata = pd.DataFrame({"Year":yr, "Region": region, "Available":avail2, "Approve":approve2})
lpncdata
# Out:
#        Year  Region  Available    Approve
# 0      2008       2          1  18.095789
# 1      2000       1          0  10.176033
# 2      2001       3          0  56.116278
# 3      2004       3          1  56.125248
# 4      2005       3          1  60.316645
# ...     ...     ...        ...        ...
# 99995  2002       3          0  41.300125
# 99996  2002       3          0  29.461023
# 99997  2007       4          1  89.476132
# 99998  2000       1          0  54.677766
# 99999  2007       1          1   9.064052
#
# [100000 rows x 4 columns]

# %% [markdown]
# The following crosstab shows the steady increase in access to PNC starting in 2003.

# %% [markdown]
# **Question 1.4. Use `sns.lineplot` to show what proportion of citizens have access to LPNC by year.**

# %%
sns.lineplot(x='Year', y="Available", data=lpncdata)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Available'>

# %% [markdown]
# **Question  1.4. Show that a regression with only year fixed effects does not give a good estimate of the causal effect of LPNC availability on presidential approval, but a regression with both year and region fixed effects gives a good estimate of the causal effect.**

# %%
# Code for 1.4
smf.ols("Approve ~ Available + C(Year)", data= lpncdata).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Approve   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     620.3
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):               0.00
# Time:                        17:31:08   Log-Likelihood:            -4.4219e+05
# No. Observations:              100000   AIC:                         8.844e+05
# Df Residuals:                   99989   BIC:                         8.845e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          45.2389      0.201    225.150      0.000      44.845      45.633
# C(Year)[T.2001]     1.8419      0.284      6.489      0.000       1.286       2.398
# C(Year)[T.2002]     2.7299      0.284      9.597      0.000       2.172       3.287
# C(Year)[T.2003]    -1.8009      0.292     -6.177      0.000      -2.372      -1.229
# C(Year)[T.2004]    -6.2677      0.313    -20.011      0.000      -6.882      -5.654
# C(Year)[T.2005]   -11.3332      0.344    -32.917      0.000     -12.008     -10.658
# C(Year)[T.2006]   -15.8612      0.382    -41.472      0.000     -16.611     -15.112
# C(Year)[T.2007]   -15.2809      0.384    -39.801      0.000     -16.033     -14.528
# C(Year)[T.2008]   -15.0544      0.382    -39.407      0.000     -15.803     -14.306
# C(Year)[T.2009]   -14.8808      0.383    -38.865      0.000     -15.631     -14.130
# Available          19.4801      0.256     76.045      0.000      18.978      19.982
# ==============================================================================
# Omnibus:                     6051.410   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2239.237
# Skew:                           0.047   Prob(JB):                         0.00
# Kurtosis:                       2.273   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
smf.ols("Approve ~ Available + C(Year) + C(Region)", data= lpncdata).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Approve   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     3386.
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):               0.00
# Time:                        17:31:18   Log-Likelihood:            -4.2696e+05
# No. Observations:              100000   AIC:                         8.539e+05
# Df Residuals:                   99986   BIC:                         8.541e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          31.9871      0.200    159.871      0.000      31.595      32.379
# C(Year)[T.2001]     1.7996      0.244      7.382      0.000       1.322       2.277
# C(Year)[T.2002]     2.7093      0.244     11.092      0.000       2.231       3.188
# C(Year)[T.2003]     3.2837      0.252     13.037      0.000       2.790       3.777
# C(Year)[T.2004]     3.8066      0.274     13.876      0.000       3.269       4.344
# C(Year)[T.2005]     3.8567      0.307     12.575      0.000       3.256       4.458
# C(Year)[T.2006]     4.5445      0.346     13.126      0.000       3.866       5.223
# C(Year)[T.2007]     4.6955      0.347     13.541      0.000       4.016       5.375
# C(Year)[T.2008]     5.1036      0.345     14.773      0.000       4.426       5.781
# C(Year)[T.2009]     5.6707      0.347     16.348      0.000       4.991       6.351
# C(Region)[T.2]      6.2290      0.157     39.736      0.000       5.922       6.536
# C(Region)[T.3]     16.3876      0.162    100.888      0.000      16.069      16.706
# C(Region)[T.4]     30.3606      0.171    177.424      0.000      30.025      30.696
# Available          -0.8203      0.246     -3.339      0.001      -1.302      -0.339
# ==============================================================================
# Omnibus:                    88178.821   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5994.640
# Skew:                          -0.005   Prob(JB):                         0.00
# Kurtosis:                       1.801   Cond. No.                         18.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Part 2: Bringing it back full circle

# %% [markdown]
# Let's revisit an example from week 1: did the expiration of the Federal Assault Weapon ban lead to more homicides in areas of Mexico which are close to states in the US where the expiration made guns more accessible? In week 1 we just replicated a graph, now let's dig into the full replication data file from the <a href="https://www.jstor.org/stable/43654914">paper</a> by Dube, Dube, and Garcia-Ponce.
#
# The analysis we will do is related to Table 2 in their paper, though they use a somewhat different regression method (the results are similar).

# %%
ddg = pd.read_stata("cross_border_main.dta")
ddg
# Out:
#            statename        munname  muncode       year       pop  NCAseg18  \
# 0    Baja California       Mexicali   2002.0 2002-01-01  793103.0       0.0
# 1    Baja California       Mexicali   2002.0 2003-01-01  814899.0       0.0
# 2    Baja California       Mexicali   2002.0 2004-01-01  835867.0       0.0
# 3    Baja California       Mexicali   2002.0 2005-01-01  854879.0       0.0
# 4    Baja California       Mexicali   2002.0 2006-01-01  873937.0       0.0
# ..               ...            ...      ...        ...       ...       ...
# 530       Tamaulipas  Valle Hermoso  28040.0 2002-01-01   60973.0       0.0
# 531       Tamaulipas  Valle Hermoso  28040.0 2003-01-01   61583.0       0.0
# 532       Tamaulipas  Valle Hermoso  28040.0 2004-01-01   62153.0       0.0
# 533       Tamaulipas  Valle Hermoso  28040.0 2005-01-01   62769.0       0.0
# 534       Tamaulipas  Valle Hermoso  28040.0 2006-01-01   63230.0       0.0
#
#      negdistNCA18  negdist18  mindistNCA18  mindist18  ...  nppm0204p  \
# 0        0.915787   0.935095      0.084213   0.064905  ...        1.0
# 1        0.915787   0.935095      0.084213   0.064905  ...        1.0
# 2        0.915787   0.935095      0.084213   0.064905  ...        1.0
# 3        0.915787   0.935095      0.084213   0.064905  ...        1.0
# 4        0.915787   0.935095      0.084213   0.064905  ...        1.0
# ..            ...        ...           ...        ...  ...        ...
# 530      0.975491   0.975491      0.024509   0.024509  ...        0.0
# 531      0.975491   0.975491      0.024509   0.024509  ...        0.0
# 532      0.975491   0.975491      0.024509   0.024509  ...        0.0
# 533      0.975491   0.975491      0.024509   0.024509  ...        0.0
# 534      0.975491   0.975491      0.024509   0.024509  ...        0.0
#
#      lexptotalpc  ltot4drugs_value_mexp1  lmarijuana_hectaresp1  \
# 0      -6.579107               18.980207               0.574082
# 1      -6.399465               18.352587               5.392031
# 2      -6.281058               18.576866               2.872377
# 3      -6.250871               19.014620               0.000000
# 4      -6.086829               18.065960               0.000000
# ..           ...                     ...                    ...
# 530    -6.884375                0.000000               0.000000
# 531    -6.807280                0.000000               0.000000
# 532    -6.687960                0.000000               0.000000
# 533    -6.623382                0.000000               0.000000
# 534    -6.587582                0.000000               0.000000
#
#      lpoppy_hectaresp1  ltotal_4drugs_value18  ldeportable18  \
# 0             0.000000              19.488834      11.592411
# 1             3.281851              19.432281      11.430619
# 2             2.668061              19.468000      11.218111
# 3             0.000000              19.957548      10.928202
# 4             0.000000              20.603355      11.026288
# ..                 ...                    ...            ...
# 530           0.000000              17.921453      11.406754
# 531           0.000000              17.865555      11.261241
# 532           0.000000              18.394337      11.439785
# 533           0.000000              18.690708      11.806997
# 534           0.000000              18.093565      11.613051
#
#      lport_ave_earn18  port_emp_rat18  homds_sum
# 0           10.222232        0.352164      516.0
# 1           10.249273        0.356448      516.0
# 2           10.272012        0.350987      516.0
# 3           10.308653        0.353121      516.0
# 4           10.310818        0.360647      516.0
# ..                ...             ...        ...
# 530         10.038018        0.328034       19.0
# 531         10.066584        0.320439       19.0
# 532         10.094893        0.318011       19.0
# 533         10.121900        0.313354       19.0
# 534         10.157315        0.321594       19.0
#
# [535 rows x 47 columns]

# %% [markdown]
# Each row is corresponds to a year in a city (Municipio), for 2002-2006. The main dependent variables are the number of homicides (`homicides`) and gun-related homicides (`homdguns`) in that city-year. The "treatment" here is being in a city not bordering CA after 2004.
#
# First, we follow the paper in restricting analysis to cities close to the border.

# %%
ddg = ddg[ddg['border']==1].reset_index()

# %% [markdown]
# I'd like to give our main variables some more intuitive names. We are going to rename the variable indicating the city is close to a non-CA state as `non_ca`, and the indicator for being in one of these cities after 2004 as `Expire`. We can do this with the `rename` function (we'll talk about this more next week).

# %%
ddg.rename(columns={"NCAseg18xpost":"Expire", "NCAseg18":"non_ca"}, inplace=True)

# %% [markdown]
# Let's do a crosstab of the year and whether the ban expired:

# %%
pd.crosstab(ddg['year'], ddg['Expire'])
# Out:
# Expire      0.0  1.0
# year
# 2002-01-01   38    0
# 2003-01-01   38    0
# 2004-01-01   38    0
# 2005-01-01    3   35
# 2006-01-01    3   35

# %% [markdown]
# Notice that the "year" also includes a "day" and "month", which is just a function of how dates are getting passed from csv format to the notebook. The following line of code drops the 01-01.

# %%
ddg['year'] = pd.DatetimeIndex(ddg['year']).year
ddg
# Out:
#      index        statename    munname  muncode  year       pop  non_ca  \
# 0        0  Baja California   Mexicali   2002.0  2002  793103.0     0.0
# 1        1  Baja California   Mexicali   2002.0  2003  814899.0     0.0
# 2        2  Baja California   Mexicali   2002.0  2004  835867.0     0.0
# 3        3  Baja California   Mexicali   2002.0  2005  854879.0     0.0
# 4        4  Baja California   Mexicali   2002.0  2006  873937.0     0.0
# ..     ...              ...        ...      ...   ...       ...     ...
# 185    520       Tamaulipas  Río Bravo  28033.0  2002  107139.0     1.0
# 186    521       Tamaulipas  Río Bravo  28033.0  2003  107658.0     1.0
# 187    522       Tamaulipas  Río Bravo  28033.0  2004  108010.0     1.0
# 188    523       Tamaulipas  Río Bravo  28033.0  2005  108100.0     1.0
# 189    524       Tamaulipas  Río Bravo  28033.0  2006  108157.0     1.0
#
#      negdistNCA18  negdist18  mindistNCA18  ...  nppm0204p  lexptotalpc  \
# 0        0.915787   0.935095      0.084213  ...        1.0    -6.579107
# 1        0.915787   0.935095      0.084213  ...        1.0    -6.399465
# 2        0.915787   0.935095      0.084213  ...        1.0    -6.281058
# 3        0.915787   0.935095      0.084213  ...        1.0    -6.250871
# 4        0.915787   0.935095      0.084213  ...        1.0    -6.086829
# ..            ...        ...           ...  ...        ...          ...
# 185      0.966163   0.966163      0.033837  ...        0.0    -6.386595
# 186      0.966163   0.966163      0.033837  ...        0.0    -6.273474
# 187      0.966163   0.966163      0.033837  ...        0.0    -6.421165
# 188      0.966163   0.966163      0.033837  ...        0.0    -6.377628
# 189      0.966163   0.966163      0.033837  ...        0.0    -6.235785
#
#      ltot4drugs_value_mexp1  lmarijuana_hectaresp1  lpoppy_hectaresp1  \
# 0                 18.980207               0.574082           0.000000
# 1                 18.352587               5.392031           3.281851
# 2                 18.576866               2.872377           2.668061
# 3                 19.014620               0.000000           0.000000
# 4                 18.065960               0.000000           0.000000
# ..                      ...                    ...                ...
# 185                0.000000               0.000000           0.000000
# 186                0.000000               0.000000           0.000000
# 187               14.747005               0.000000           0.000000
# 188                0.000000               0.000000           0.000000
# 189                0.000000               0.000000           0.000000
#
#      ltotal_4drugs_value18  ldeportable18  lport_ave_earn18  port_emp_rat18  \
# 0                19.488834      11.592411         10.222232        0.352164
# 1                19.432281      11.430619         10.249273        0.356448
# 2                19.468000      11.218111         10.272012        0.350987
# 3                19.957548      10.928202         10.308653        0.353121
# 4                20.603355      11.026288         10.310818        0.360647
# ..                     ...            ...               ...             ...
# 185              19.176804      11.406754         10.051002        0.284943
# 186              19.453865      11.261241         10.076474        0.286849
# 187              19.647392      11.439785         10.107693        0.291741
# 188              20.119959      11.806997         10.138480        0.297265
# 189              19.287781      11.613051         10.192493        0.299326
#
#      homds_sum
# 0        516.0
# 1        516.0
# 2        516.0
# 3        516.0
# 4        516.0
# ..         ...
# 185       33.0
# 186       33.0
# 187       33.0
# 188       33.0
# 189       33.0
#
# [190 rows x 48 columns]

# %% [markdown]
# One notable thing here is that we don't have a lot of cities close to CA: we can see this because there are just 3 observations in 2005 and 2006 where the ban didn't expire.

# %% [markdown]
# **Question 2.1. Use `smf.ols` to run a regression with the count of homicides (`homicide`) and as the dependent variable and `Expire` as the independent variable. Why might this not be a good estimate of the effect of the expiration of the ban?**

# %%
# Code for 2.1
smf.ols("homicide ~ Expire", data=ddg).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               homicide   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.369
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):              0.243
# Time:                        17:31:45   Log-Likelihood:                -1045.7
# No. Observations:                 190   AIC:                             2095.
# Df Residuals:                     188   BIC:                             2102.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     29.2417      5.453      5.362      0.000      18.484      39.999
# Expire       -10.5131      8.984     -1.170      0.243     -28.236       7.210
# ==============================================================================
# Omnibus:                      149.259   Durbin-Watson:                   0.514
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1080.081
# Skew:                           3.220   Prob(JB):                    2.91e-235
# Kurtosis:                      12.744   Cond. No.                         2.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# There are two potential problems, as in the first part of the lab. It may be the case that violence was trending up or down over time, and so the city-years after experition could have higher or lower levels of violence for unrelated reasons. Second, it may be the case that the cities close to CA were more or less violent in this time window for other reasons>

# %% [markdown]
# **Question 2.2. Use `smf.ols` to run a regression with the number of homicides as the dependent variable, and `Expire` and city fixed effects as dependent variables. (Hint: the `munname` variable is a string corresponding to each city, so we don't need to create a new to add fixed effects.)**

# %%
# Code for 2.2
smf.ols("homicide ~ Expire + C(munname)", data=ddg).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               homicide   R-squared:                       0.967
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     121.9
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):           2.28e-95
# Time:                        17:31:57   Log-Likelihood:                -721.16
# No. Observations:                 190   AIC:                             1518.
# Df Residuals:                     152   BIC:                             1642.
# Df Model:                          37
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       7.7257      5.435      1.421      0.157      -3.013      18.464
# C(munname)[T.Agua Prieta]                       2.0000      7.614      0.263      0.793     -13.044      17.044
# C(munname)[T.Altar]                            -6.2000      7.614     -0.814      0.417     -21.244       8.844
# C(munname)[T.Anáhuac]                          -4.2000      7.614     -0.552      0.582     -19.244      10.844
# C(munname)[T.Ascensión]                        -2.4000      7.614     -0.315      0.753     -17.444      12.644
# C(munname)[T.Caborca]                           1.4000      7.614      0.184      0.854     -13.644      16.444
# C(munname)[T.Camargo]                          -7.4000      7.614     -0.972      0.333     -22.444       7.644
# C(munname)[T.Coyame del Sotol]                 -9.4000      7.614     -1.234      0.219     -24.444       5.644
# C(munname)[T.General Plutarco Elías Calles]    -4.0000      7.614     -0.525      0.600     -19.044      11.044
# C(munname)[T.Guadalupe]                        -6.4000      7.614     -0.841      0.402     -21.444       8.644
# C(munname)[T.Guerrero]                         -8.2000      6.594     -1.243      0.216     -21.228       4.828
# C(munname)[T.Gustavo Díaz Ordaz]               -8.4000      7.614     -1.103      0.272     -23.444       6.644
# C(munname)[T.Hidalgo]                          -8.4000      7.614     -1.103      0.272     -23.444       6.644
# C(munname)[T.Janos]                            -8.8000      7.614     -1.156      0.250     -23.844       6.244
# C(munname)[T.Jiménez]                          -8.0000      7.614     -1.051      0.295     -23.044       7.044
# C(munname)[T.Juárez]                          215.4000      7.614     28.288      0.000     200.356     230.444
# C(munname)[T.Manuel Benavides]                 -9.0000      7.614     -1.182      0.239     -24.044       6.044
# C(munname)[T.Matamoros]                        28.8000      7.614      3.782      0.000      13.756      43.844
# C(munname)[T.Mexicali]                         95.4743      7.651     12.479      0.000      80.359     110.590
# C(munname)[T.Mier]                             -9.2000      7.614     -1.208      0.229     -24.244       5.844
# C(munname)[T.Miguel Alemán]                    -5.8000      7.614     -0.762      0.447     -20.844       9.244
# C(munname)[T.Naco]                             -8.4000      7.614     -1.103      0.272     -23.444       6.644
# C(munname)[T.Nava]                             -8.0000      7.614     -1.051      0.295     -23.044       7.044
# C(munname)[T.Nogales]                          25.6000      7.614      3.362      0.001      10.556      40.644
# C(munname)[T.Nuevo Laredo]                     90.2000      7.614     11.846      0.000      75.156     105.244
# C(munname)[T.Ocampo]                           -9.0000      7.614     -1.182      0.239     -24.044       6.044
# C(munname)[T.Ojinaga]                          -4.8000      7.614     -0.630      0.529     -19.844      10.244
# C(munname)[T.Piedras Negras]                    3.6000      7.614      0.473      0.637     -11.444      18.644
# C(munname)[T.Praxedis G. Guerrero]             -8.2000      7.614     -1.077      0.283     -23.244       6.844
# C(munname)[T.Puerto Peñasco]                   -4.2000      7.614     -0.552      0.582     -19.244      10.844
# C(munname)[T.Reynosa]                          35.2000      7.614      4.623      0.000      20.156      50.244
# C(munname)[T.Río Bravo]                        -2.8000      7.614     -0.368      0.714     -17.844      12.244
# C(munname)[T.San Luis Río Colorado]             9.4000      7.614      1.234      0.219      -5.644      24.444
# C(munname)[T.Santa Cruz]                       -8.8000      7.614     -1.156      0.250     -23.844       6.244
# C(munname)[T.Sáric]                            -4.8000      7.614     -0.630      0.529     -19.844      10.244
# C(munname)[T.Tecate]                            6.2743      7.651      0.820      0.413      -8.841      21.390
# C(munname)[T.Tijuana]                         271.4743      7.651     35.484      0.000     256.359     286.590
# Expire                                          4.1857      1.858      2.253      0.026       0.515       7.856
# ==============================================================================
# Omnibus:                      101.813   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2445.755
# Skew:                           1.428   Prob(JB):                         0.00
# Kurtosis:                      20.343   Cond. No.                         41.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Question 2.3. Now run the previous regression but with year fixed effects added (remember to use a `C()` to treat the year as categorical). How does this affect our estimate of the causal effect in question?**

# %%
# Code for 2.3
smf.ols("homicide ~ Expire + C(munname) + C(year)", data=ddg).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               homicide   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     107.6
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):           2.36e-91
# Time:                        17:32:07   Log-Likelihood:                -720.77
# No. Observations:                 190   AIC:                             1526.
# Df Residuals:                     148   BIC:                             1662.
# Df Model:                          41
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       7.6292      5.729      1.332      0.185      -3.691      18.950
# C(munname)[T.Agua Prieta]                       2.0000      7.701      0.260      0.795     -13.218      17.218
# C(munname)[T.Altar]                            -6.2000      7.701     -0.805      0.422     -21.418       9.018
# C(munname)[T.Anáhuac]                          -4.2000      7.701     -0.545      0.586     -19.418      11.018
# C(munname)[T.Ascensión]                        -2.4000      7.701     -0.312      0.756     -17.618      12.818
# C(munname)[T.Caborca]                           1.4000      7.701      0.182      0.856     -13.818      16.618
# C(munname)[T.Camargo]                          -7.4000      7.701     -0.961      0.338     -22.618       7.818
# C(munname)[T.Coyame del Sotol]                 -9.4000      7.701     -1.221      0.224     -24.618       5.818
# C(munname)[T.General Plutarco Elías Calles]    -4.0000      7.701     -0.519      0.604     -19.218      11.218
# C(munname)[T.Guadalupe]                        -6.4000      7.701     -0.831      0.407     -21.618       8.818
# C(munname)[T.Guerrero]                         -8.2000      6.669     -1.230      0.221     -21.379       4.979
# C(munname)[T.Gustavo Díaz Ordaz]               -8.4000      7.701     -1.091      0.277     -23.618       6.818
# C(munname)[T.Hidalgo]                          -8.4000      7.701     -1.091      0.277     -23.618       6.818
# C(munname)[T.Janos]                            -8.8000      7.701     -1.143      0.255     -24.018       6.418
# C(munname)[T.Jiménez]                          -8.0000      7.701     -1.039      0.301     -23.218       7.218
# C(munname)[T.Juárez]                          215.4000      7.701     27.971      0.000     200.182     230.618
# C(munname)[T.Manuel Benavides]                 -9.0000      7.701     -1.169      0.244     -24.218       6.218
# C(munname)[T.Matamoros]                        28.8000      7.701      3.740      0.000      13.582      44.018
# C(munname)[T.Mexicali]                         97.2298      8.152     11.927      0.000      81.120     113.340
# C(munname)[T.Mier]                             -9.2000      7.701     -1.195      0.234     -24.418       6.018
# C(munname)[T.Miguel Alemán]                    -5.8000      7.701     -0.753      0.453     -21.018       9.418
# C(munname)[T.Naco]                             -8.4000      7.701     -1.091      0.277     -23.618       6.818
# C(munname)[T.Nava]                             -8.0000      7.701     -1.039      0.301     -23.218       7.218
# C(munname)[T.Nogales]                          25.6000      7.701      3.324      0.001      10.382      40.818
# C(munname)[T.Nuevo Laredo]                     90.2000      7.701     11.713      0.000      74.982     105.418
# C(munname)[T.Ocampo]                           -9.0000      7.701     -1.169      0.244     -24.218       6.218
# C(munname)[T.Ojinaga]                          -4.8000      7.701     -0.623      0.534     -20.018      10.418
# C(munname)[T.Piedras Negras]                    3.6000      7.701      0.467      0.641     -11.618      18.818
# C(munname)[T.Praxedis G. Guerrero]             -8.2000      7.701     -1.065      0.289     -23.418       7.018
# C(munname)[T.Puerto Peñasco]                   -4.2000      7.701     -0.545      0.586     -19.418      11.018
# C(munname)[T.Reynosa]                          35.2000      7.701      4.571      0.000      19.982      50.418
# C(munname)[T.Río Bravo]                        -2.8000      7.701     -0.364      0.717     -18.018      12.418
# C(munname)[T.San Luis Río Colorado]             9.4000      7.701      1.221      0.224      -5.818      24.618
# C(munname)[T.Santa Cruz]                       -8.8000      7.701     -1.143      0.255     -24.018       6.418
# C(munname)[T.Sáric]                            -4.8000      7.701     -0.623      0.534     -20.018      10.418
# C(munname)[T.Tecate]                            8.0298      8.152      0.985      0.326      -8.080      24.140
# C(munname)[T.Tijuana]                         273.2298      8.152     33.516      0.000     257.120     289.340
# C(year)[T.2003]                                -0.0526      2.793     -0.019      0.985      -5.573       5.468
# C(year)[T.2004]                                 0.3421      2.793      0.122      0.903      -5.178       5.862
# C(year)[T.2005]                                -4.7661      6.763     -0.705      0.482     -18.130       8.598
# C(year)[T.2006]                                -3.8187      6.763     -0.565      0.573     -17.183       9.545
# Expire                                          8.5746      6.687      1.282      0.202      -4.639      21.789
# ==============================================================================
# Omnibus:                      103.703   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2448.548
# Skew:                           1.477   Prob(JB):                         0.00
# Kurtosis:                      20.337   Cond. No.                         44.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# *Words for 2.3*

# %% [markdown]
# **Question 2.4. Repeat this analysis with gun-related homicides (`homdguns`) as the dependent variable. What is the estimate of the causal effect of the expiration of the ban (using city and year fixed effects)?**

# %%
# Code for 2.4
smf.ols("homdguns ~ Expire + C(munname) + C(year)", data=ddg).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               homdguns   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.927
# Method:                 Least Squares   F-statistic:                     59.23
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):           3.05e-73
# Time:                        17:32:11   Log-Likelihood:                -688.04
# No. Observations:                 190   AIC:                             1460.
# Df Residuals:                     148   BIC:                             1596.
# Df Model:                          41
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       2.0417      4.822      0.423      0.673      -7.487      11.571
# C(munname)[T.Agua Prieta]                       4.6000      6.482      0.710      0.479      -8.210      17.410
# C(munname)[T.Altar]                            -1.6000      6.482     -0.247      0.805     -14.410      11.210
# C(munname)[T.Anáhuac]                           1.2000      6.482      0.185      0.853     -11.610      14.010
# C(munname)[T.Ascensión]                         1.4000      6.482      0.216      0.829     -11.410      14.210
# C(munname)[T.Caborca]                           2.4000      6.482      0.370      0.712     -10.410      15.210
# C(munname)[T.Camargo]                          -2.8000      6.482     -0.432      0.666     -15.610      10.010
# C(munname)[T.Coyame del Sotol]                 -3.6000      6.482     -0.555      0.579     -16.410       9.210
# C(munname)[T.General Plutarco Elías Calles]  -9.77e-15      6.482  -1.51e-15      1.000     -12.810      12.810
# C(munname)[T.Guadalupe]                        -1.4000      6.482     -0.216      0.829     -14.210      11.410
# C(munname)[T.Guerrero]                         -2.9000      5.614     -0.517      0.606     -13.994       8.194
# C(munname)[T.Gustavo Díaz Ordaz]               -3.2000      6.482     -0.494      0.622     -16.010       9.610
# C(munname)[T.Hidalgo]                          -2.6000      6.482     -0.401      0.689     -15.410      10.210
# C(munname)[T.Janos]                            -3.4000      6.482     -0.525      0.601     -16.210       9.410
# C(munname)[T.Jiménez]                          -3.2000      6.482     -0.494      0.622     -16.010       9.610
# C(munname)[T.Juárez]                          126.6000      6.482     19.530      0.000     113.790     139.410
# C(munname)[T.Manuel Benavides]                 -3.2000      6.482     -0.494      0.622     -16.010       9.610
# C(munname)[T.Matamoros]                        17.4000      6.482      2.684      0.008       4.590      30.210
# C(munname)[T.Mexicali]                         73.0051      6.862     10.639      0.000      59.445      86.565
# C(munname)[T.Mier]                             -3.4000      6.482     -0.525      0.601     -16.210       9.410
# C(munname)[T.Miguel Alemán]                    -1.0000      6.482     -0.154      0.878     -13.810      11.810
# C(munname)[T.Naco]                             -2.6000      6.482     -0.401      0.689     -15.410      10.210
# C(munname)[T.Nava]                             -2.6000      6.482     -0.401      0.689     -15.410      10.210
# C(munname)[T.Nogales]                          19.6000      6.482      3.024      0.003       6.790      32.410
# C(munname)[T.Nuevo Laredo]                     72.0000      6.482     11.107      0.000      59.190      84.810
# C(munname)[T.Ocampo]                           -3.4000      6.482     -0.525      0.601     -16.210       9.410
# C(munname)[T.Ojinaga]                          -1.2000      6.482     -0.185      0.853     -14.010      11.610
# C(munname)[T.Piedras Negras]                    2.8000      6.482      0.432      0.666     -10.010      15.610
# C(munname)[T.Praxedis G. Guerrero]             -2.8000      6.482     -0.432      0.666     -15.610      10.010
# C(munname)[T.Puerto Peñasco]                   -2.2000      6.482     -0.339      0.735     -15.010      10.610
# C(munname)[T.Reynosa]                          19.0000      6.482      2.931      0.004       6.190      31.810
# C(munname)[T.Río Bravo]                        -0.4000      6.482     -0.062      0.951     -13.210      12.410
# C(munname)[T.San Luis Río Colorado]             8.2000      6.482      1.265      0.208      -4.610      21.010
# C(munname)[T.Santa Cruz]                       -3.2000      6.482     -0.494      0.622     -16.010       9.610
# C(munname)[T.Sáric]                            -0.2000      6.482     -0.031      0.975     -13.010      12.610
# C(munname)[T.Tecate]                            7.0051      6.862      1.021      0.309      -6.555      20.565
# C(munname)[T.Tijuana]                         172.0051      6.862     25.066      0.000     158.445     185.565
# C(year)[T.2003]                                 0.6316      2.351      0.269      0.789      -4.015       5.278
# C(year)[T.2004]                                -0.1053      2.351     -0.045      0.964      -4.752       4.541
# C(year)[T.2005]                                -1.4854      5.693     -0.261      0.795     -12.735       9.764
# C(year)[T.2006]                                 0.7251      5.693      0.127      0.899     -10.524      11.974
# Expire                                          4.0127      5.629      0.713      0.477      -7.110      15.136
# ==============================================================================
# Omnibus:                       97.687   Durbin-Watson:                   1.700
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2929.937
# Skew:                           1.256   Prob(JB):                         0.00
# Kurtosis:                      22.073   Cond. No.                         44.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The coefficient on "expire" is still positive, though it is smaller (and not statistically significant.)
